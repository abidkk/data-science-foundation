# %% [markdown]
# ## Python Exception Handling
# Python Exception Handling allows a program to gracefully handle unexpected events (like invalid input or missing files) without crashing. Instead of terminating abruptly, Python lets you detect the problem, respond to it, and continue execution when possible.

# %% [markdown]
# ### Difference Between Errors and Exceptions
# - Errors and exceptions are both issues in a program, but they differ in severity and handling. Let's see how:
# Error: Serious problems in the program logic that cannot be handled. Examples include syntax errors or memory errors.
#
# - Exception: Less severe problems that occur at runtime and can be managed using exception handling (e.g., invalid input, missing files).!
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Python provides four main keywords for handling exceptions: try, except, else and finally each plays a unique role. Let's see syntax:
#
# - try: Runs the risky code that might cause an error.
# - except: Catches and handles the error if one occurs.
# - else: Executes only if no exception occurs in try.
# - finally: Runs regardless of what happens useful for cleanup tasks like closing files.

# %% [markdown]
# ## Try & Except

# %%
print(25/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(25/0)
#
# ZeroDivisionError: division by zero

# %%
## Handling Zero Division Error
try:
    print(25/0)
except ZeroDivisionError:
    print("Can't not divide by zero")
# Out:
# Can't not divide by zero

# %%
try:
    print(25/0)
except Exception as e: ## for unidentified error
    print(e)
# Out:
# division by zero

# %%
n1 = int(input("Please enter first  number: "))
n2 = int(input("Please enter second number: "))
print(f"n1: {n1}, n2{n2}")

try:
    print(n1/n2)

except Exception as err:
    print(err)
# Out:
# n1: 30, n25
# 6.0

# %%
## Error case
n1 = int(input("Please enter first  number: "))
n2 = int(input("Please enter second number: "))
print(f"n1: {n1}, n2: {n2}")

try:
    print(n1/n2)

except Exception as err:
    print(err)
# Out:
# n1: 30, n2: 0
# division by zero

# %%
## Error case
n1 = int(input("Please enter first  number: "))
n2 = int(input("Please enter second number: "))
print(f"n1: {n1}, n2: {n2}")

try:
    res = n1/n2
    print(n1/n2)
except Exception as err:
    print(err)
else:  ## execute only when no exception
    print("Result: ", res)
# Out:
# n1: 30, n2: 4
# 7.5
# Result:  7.5

# %%
## Error case
n1 = int(input("Please enter first  number: "))
n2 = int(input("Please enter second number: "))
print(f"n1: {n1}, n2: {n2}")

try:
    res = n1/n2
    print(n1/n2)
except Exception as err:
    print(err)
else:  ## execute only when no exception
    print("Result: ", res)
finally:
    print("Task Finished") ## always execute to show the completeness
# Out:
# n1: 40, n2: 0
# division by zero
# Task Finished

# %%
a , b = 10,20,30
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a , b = 10,20,30
#
# ValueError: too many values to unpack (expected 2)

# %%
try:
    a , b = 10,20,30
    print(a+b)
except Exception as err:
    print(err)
finally:
    print("Task Ended")
# Out:
# too many values to unpack (expected 2)
# Task Ended

# %%
try:
    a , b = 10,20,30
    print(a+b)
except: ## Extreme general case
    print("Something went wrong")
finally:
    print("Task Ended")
# Out:
# Something went wrong
# Task Ended
