# %% [markdown]
# ## Python Packages
# Python packages are a way to organize and structure code by grouping related modules into directories.
#
# A package is essentially a folder that contains an __init__.py file and one or more Python files (modules).
# Allows modules to be easily shared and distributed across different applications.
#
# ##### Key Components of a Python Package
# - Module: A single Python file containing reusable code (e.g., math.py).
# - Package: A directory containing modules and a special __init__.py file.
# - Sub-Packages: Packages nested within other packages for deeper organization.

# %% [markdown]
# ### 📦 What is a Module in Python?
#
# A module is simply:
#
# A Python file (.py) that contains code (functions, variables, classes) which you can reuse in another file.
#
#
# #### 🎯 Why Modules Exist (Real Software Engineering Reason)
#
# Imagine writing everything in one file:
#
#  2000 lines of code
#
# Problems:
#
# - Hard to read
# - Hard to debug
# - Hard to reuse
# - Hard to collaborate
# - So we split code into logical pieces.
#
# Example in your future FastAPI project:
#
# - app.py
# - database.py
# - models.py
# - routes.py
# - auth.py
#
# Each file = a module.
#
# That’s clean architecture.

# %%
from calculator import add
print(add(10,20))
# Out:
# 30

# %%
import calculator ## import calculator file

print(calculator.multiply(10,29)) ##

print(calculator.add(10,29)) ##
# Out:
# 290
# 39

# %% [markdown]
# ## 📦 What is a Package?
# Since you're moving toward production APIs.
# A package is: A folder containing multiple modules
#
# Example:
#
# - myapp/
#     - __init__.py
#     - routes.py
#     - models.py
#     - utils.py
#
# Folder = package
# Files inside = modules
